# %% [markdown]
# # Twitter Data Processing Pipeline with Dask and Incremental Writes

# %% [markdown]
# ## Introduction
#
# This notebook provides a complete pipeline for processing tweet data, optimized for large datasets using Dask.
# It also includes incremental writes to a CSV file to save progress.

# %%
import warnings
import pandas as pd
import json
import csv
import requests
from typing import Dict, List, Any
import logging
import numpy as np
import concurrent.futures
import os

# %%
warnings.filterwarnings(action='ignore', category=FutureWarning)
# warnings.filterwarnings(action='ignore', category=FutureWarning, module='pyspark')

# %%
# Initialize Spark session
# Configure logging
logging.basicConfig(level=logging.INFO)
logging.basicConfig(filename='processing.log', level=logging.INFO)
# spark = SparkSession.builder \
#     .appName("Twitter Data Processing") \
#     .getOrCreate()

# %%
# data_name = 'streamV2_tweetnet_2023-06'

# %%
# Read the JSONL file
# df = pd.read_json(f'../data/{data_name}.jsons', lines=True)

# %%
# Define the transformation function
def extract_fields(json_obj):
    tweet_id = json_obj.get('tweet_id', '')
    tweet_type = json_obj.get('tweet_type', '')
    hashtags = json_obj.get('hashtags', [])
    mentions = json_obj.get('mentions', [])
    return {
        'tweet_id': tweet_id,
        'tweet_type': tweet_type,
        'hashtags': hashtags,
        'mentions': mentions
    }

# %%
# API call
def fetch_additional_info(tweet_id):
    url = "https://cdn.syndication.twimg.com/tweet-result"
    querystring = {"id": tweet_id, "lang": "en", "token": "x"}
    payload = ""
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate, br",
    "Origin": "https://platform.twitter.com",
    "Connection": "keep-alive",
    "Referer": "https://platform.twitter.com/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "cross-site",
    "Pragma": "no-cache",
    "Cache-Control": "no-cache",
    "TE": "trailers"
    }
    try:
        response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
        if response.status_code != 200:
            # print(f"Failed to fetch additional info for tweet_id {tweet_id}")
            return None
    except Exception as e:
        logging.error(f'Failed to fetch additional info for tweet_id {tweet_id}')
        return None
    return response.text

# %%
fetch_additional_info(1630682530465587204)
# Out:
# '{"__typename":"Tweet","in_reply_to_screen_name":"DrSinanOgan","in_reply_to_status_id_str":"1664012893799448579","in_reply_to_user_id_str":"177884455","lang":"und","favorite_count":0,"created_at":"2023-05-31T20:59:55.000Z","display_text_range":[13,22],"entities":{"hashtags":[],"urls":[],"user_mentions":[{"id_str":"177884455","indices":[0,12],"name":"Dr. Sinan Oğan","screen_name":"DrSinanOgan"}],"symbols":[]},"id_str":"1664013863526735874","text":"@DrSinanOgan Offf 🤦🤦","user":{"id_str":"1256361951862689797","name":"Ivan Karamazov","profile_image_url_https":"https://pbs.twimg.com/profile_images/1673470909993168899/vHLg8HHU_normal.jpg","screen_name":"fyodorkrmzv","verified":false,"is_blue_verified":false,"profile_image_shape":"Circle"},"edit_control":{"edit_tweet_ids":["1664013863526735874"],"editable_until_msecs":"1685568595000","is_edit_eligible":false,"edits_remaining":"5"},"conversation_count":0,"news_action_type":"conversation","parent":{"lang":"tr","reply_count":14714,"retweet_count":3083,"favorite_count":59300,"created_at":"2023-05-31T20:56:04.000Z","display_text_range":[0,110],"entities":{"hashtags":[],"urls":[],"user_mentions":[],"symbols":[]},"id_str":"1664012893799448579","text":"Politikada hiçbir şey kazayla olmaz. Olmuşsa, öyle planlanmıştır. \\n\\nFranklin D. Roosevelt \\n\\n“Plana sadık kal…”","user":{"id_str":"177884455","name":"Dr. Sinan Oğan","profile_image_url_https":"https://pbs.twimg.com/profile_images/1641427925999255552/L8qSHmtu_normal.jpg","screen_name":"DrSinanOgan","verified":false,"is_blue_verified":true,"profile_image_shape":"Circle"},"edit_control":{"edit_tweet_ids":["1664012893799448579"],"editable_until_msecs":"1685568364000","is_edit_eligible":true,"edits_remaining":"5"},"isEdited":false,"isStaleEdit":false},"isEdited":false,"isStaleEdit":false}'

# %%
def parse_api_response(api_response):
    if not api_response:
        return {}
    try:
        parsed_data = json.loads(api_response)
    except json.JSONDecodeError:
        logging.error(f'Failed parse_api_response {api_response}')
        return {}
    
    lang = parsed_data.get('lang', '')
    favorite_count = parsed_data.get('favorite_count', 0)
    created_at = parsed_data.get('created_at', '')
    text = parsed_data.get('text', '')
    parent_tweet_id = parsed_data.get('parent', {}).get('id_str', '')
    
    return {
        'lang': lang,
        'favorite_count': favorite_count,
        'created_at': created_at,
        'text': text,
        'parent_tweet_id': parent_tweet_id
    }

# %%
# parsed_api_response_test = parse_api_response(api_response_test)

# %%
# this cell not used

# # Initialize a CSV writer and write the header
# with open(f'output_{data_name}.csv', 'w', newline='') as f:
#     writer = csv.DictWriter(f, fieldnames=['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id'])
#     writer.writeheader()

# Function to write a single row to the CSV file
def write_row_to_csv(row):
    try:
        with open('output_{data_name}.csv', 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id'])
            writer.writerow(row)
    except Exception as e:
        print(f"Failed to write row to CSV: {e}")


# Function to process a single JSON object (this includes the API call)
def process_json_object(json_obj):
    try: 
        # Extract initial fields
        row = extract_fields(json_obj)
        
        # Fetch additional info from API (You'll have to add your API logic)
        api_response = fetch_additional_info(row['tweet_id'])
        
        # Parse the API response
        additional_info = parse_api_response(api_response)
        
        # Merge initial data and additional info
        row.update(additional_info)
        
        # Write the row to CSV
        write_row_to_csv(row)
    except Exception as e:
        print(f"Failed to process JSON object: {e}")

# %%
def custom_write_csv(df: pd.DataFrame, output_path: str, data_name: str):
    file_name = os.path.join(output_path, f'output_{data_name}.csv')
    try:
        df.to_csv(file_name, mode='a', index=False, header=False)
    except Exception as e:
        logging.error(f'Failed to write chunk {e}')
        

# Define a function to process a chunk of data
def process_chunk(df_chunk: pd.DataFrame, output_path: str, data_name: str):
    logging.info(f'Processing chunk entered')
    results = []
    for idx, row in df_chunk.iterrows():
        row_dict = row.to_dict()
        logging.info(f'Processing tweet id: {row_dict["tweet_id"]}')
        api_response = fetch_additional_info(row_dict['tweet_id'])
        additional_info = parse_api_response(api_response)
        row_dict.update(additional_info)
        # Convert hashtags and mentions array to a comma-separated string
        row_dict['hashtags'] = ','.join(row_dict['hashtags']) if isinstance(row_dict['hashtags'], (list, tuple)) else ''
        row_dict['mentions'] = ','.join(row_dict['mentions']) if isinstance(row_dict['mentions'], (list, tuple)) else ''
        results.append(row_dict)
    result_df = pd.DataFrame(results)
    # Filter the DataFrame to only include the columns specified in the schema
    result_df = result_df[['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id']]
    custom_write_csv(result_df, output_path, data_name)  # Pass output_path and data_name to custom_write_csv

def process_data_in_parallel(df, output_path: str, data_name: str):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        chunks = np.array_split(df, 10)
        # Use a lambda function to pass the output_path and data_name arguments to process_chunk
        executor.map(lambda chunk: process_chunk(chunk, output_path, data_name), chunks)

# %%
input_folder_path = './test_Folder'
output_folder_path = '../data/output/test_Folder'
os.makedirs(output_folder_path, exist_ok=True)  # Create output folder if it doesn't exist

def process_file(file_path, output_path):
    # Extract data_name from the file path
    data_name = os.path.basename(file_path).replace('.jsons', '')
    df = pd.read_json(file_path, lines=True)
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)
    
    # Write the header to the output file
    output_file = os.path.join(output_path, f'output_{data_name}.csv')
    header_df = pd.DataFrame(columns=['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id'])
    header_df.to_csv(output_file, index=False)
    
    # Process each chunk in parallel
    process_data_in_parallel(df, output_path, data_name)

def process_all_files_in_folder(folder_path, output_folder_path):
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.jsons'):
            file_path = os.path.join(folder_path, file_name)
            logging.info(f'Processing file: {file_name}')
            process_file(file_path, output_folder_path)

# %%
process_all_files_in_folder(input_folder_path, output_folder_path)

# %%
# # Call the function to process all files in the specified folder
# file_path = "./test_Folder/streamV2_tweetnet_2023-06_0.jsons"
# # Extract data_name from the file path
# data_name = os.path.basename(file_path).replace('.jsons', '')
# df = pd.read_json(file_path, lines=True)
# output_file = os.path.join(output_folder_path, f'output_{data_name}.csv')  # Update this line to use output_folder_path

#     # Write the header to the output file
# header_df = pd.DataFrame(columns=['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id'])
# header_df.to_csv(output_file, index=False)
# process_chunk(df, output_file)

# %% [markdown]
# ## Test

# %%
import warnings
import pandas as pd
import json
import csv
import requests
from typing import Dict, List, Any
import logging
import numpy as np
import concurrent.futures
import os
import re

# Define the transformation function
def extract_fields(json_obj):
    tweet_id = json_obj.get('tweet_id', '')
    tweet_type = json_obj.get('tweet_type', '')
    hashtags = json_obj.get('hashtags', [])
    mentions = json_obj.get('mentions', [])
    return {
        'tweet_id': tweet_id,
        'tweet_type': tweet_type,
        'hashtags': hashtags,
        'mentions': mentions
    }

# API call
def fetch_additional_info(tweet_id):
    url = "https://cdn.syndication.twimg.com/tweet-result"
    querystring = {"id": tweet_id, "lang": "en", "token": "x"}
    payload = ""
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate, br",
    "Origin": "https://platform.twitter.com",
    "Connection": "keep-alive",
    "Referer": "https://platform.twitter.com/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "cross-site",
    "Pragma": "no-cache",
    "Cache-Control": "no-cache",
    "TE": "trailers"
    }
    try:
        response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
        if response.status_code != 200:
            # print(f"Failed to fetch additional info for tweet_id {tweet_id}")
            return None
    except Exception as e:
        logging.error(f'Failed to fetch additional info for tweet_id {tweet_id}')
        return None
    return response.text

# Extract the additional info from API response
def parse_api_response(api_response):
    if not api_response:
        return {}
    try:
        parsed_data = json.loads(api_response)
    except json.JSONDecodeError:
        logging.error(f'Failed: parse_api_response. Error.')
        return {}
    
    lang = parsed_data.get('lang', '')
    favorite_count = parsed_data.get('favorite_count', 0)
    created_at = parsed_data.get('created_at', '')
    text = parsed_data.get('text', '')
    parent_tweet_id = parsed_data.get('parent', {}).get('id_str', '')

    # New:
    hashtags = parsed_data.get('entities', {}).get('hashtags', '')
    mentions = parsed_data.get('user_mentions', {}).get('user_mentions', '')
    tweet_type = parsed_data.get('__typename', '')
    tweet_id = parsed_data.get('id_str', '')

    return {
        'tweet_id': tweet_id,
        'tweet_type': tweet_type,
        'hashtags': hashtags,
        'mentions': mentions,
        'lang': lang,
        'favorite_count': favorite_count,
        'created_at': created_at,
        'text': text,
        'parent_tweet_id': parent_tweet_id,         
    }

# Last function in the process, which converts dataframe to csv file
def custom_write_csv(df: pd.DataFrame, output_path: str, data_name: str):
    file_name = os.path.join(output_path, f'output_{data_name}.csv')
    try:
        df.to_csv(file_name, mode='a', index=False, header=False)
    except Exception as e:
        logging.error(f'Failed to write chunk {e}')
        

# Processes a chunk of data. The function is used in process_data_in_parallel, which chunks the given df into 10 chunks
def process_chunk(df_chunk: pd.DataFrame, output_path: str, data_name: str):
    results = []

    for idx, row in df_chunk.iterrows():
        row_dict = row.to_dict()
        try:
            api_response = fetch_additional_info(row_dict['tweet_id'])
            additional_info = parse_api_response(api_response)
            row_dict.update(additional_info)
        except Exception as e: 
            logging.error(f'Failed to process chunk {e}')

        # Convert hashtags and mentions array to a comma-separated string
        #row_dict['hashtags'] = ','.join(row_dict['hashtags']) if isinstance(row_dict['hashtags'], (list, tuple)) else ''
        #row_dict['mentions'] = ','.join(row_dict['mentions']) if isinstance(row_dict['mentions'], (list, tuple)) else ''
        results.append(row_dict)
        #print(f"results inside: {results}")
    #print(f"Results after everything: {results}")
    result_df = pd.DataFrame(results)
    #print(f"Result_df: {result_df}")
    
    # Filter the DataFrame to only include the columns specified in the schema
    #result_df = result_df[['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id', 'entities']]
    
    custom_write_csv(result_df, output_path, data_name)  # Pass output_path and data_name to custom_write_csv

# Used for parallel processing, main function here is process_chunk
def process_data_in_parallel(df, output_path: str, data_name: str):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        chunks = np.array_split(df, 10)
        # Use a lambda function to pass the output_path and data_name arguments to process_chunk
        executor.map(lambda chunk: process_chunk(chunk, output_path, data_name), chunks)

# processes a file, which is written for .txt, calls process_data_in_parallel
def process_file(file_path, output_path):
    logging.info(f'Processing file path: {file_path}')
    # Extract data_name from the file path
    data_name = os.path.basename(file_path).replace('.txt', '')
    
    # Read txt file and convert it to DataFrame
    with open(file_path, 'r') as file:
        tweet_ids = [int(line.strip()) for line in file]
    df = pd.DataFrame(tweet_ids, columns=['tweet_id'])
    # Create the output directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)
    
    # Write the header to the output file
    output_file = os.path.join(output_path, f'output_{data_name}.csv')
    header_df = pd.DataFrame(columns=['tweet_id', 'tweet_type', 'hashtags', 'mentions', 'lang', 'favorite_count', 'created_at', 'text', 'parent_tweet_id'])
    header_df.to_csv(output_file, index=False)
    
    # Process each chunk in parallel
    process_data_in_parallel(df, output_path, data_name)

# Processes all the files in the folder, calls process_file
# def process_all_files_in_folder(folder_path, output_folder_path):
#     for file_name in os.listdir(folder_path):
#         if file_name.endswith('.txt'):
#             file_path = os.path.join(folder_path, file_name)
#             logging.info(f'Processing file: {file_name}')
#             process_file(file_path, output_folder_path)

def extract_number(filename):
    # Regular expression to match a sequence of digits
    match = re.search(r'_(\d+)\.txt$', filename)
    return int(match.group(1)) if match else 0

def process_all_files_in_folder(folder_path, output_folder_path):
    # Get all files in folder_path that end with .txt
    files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]
    # Sort files based on the numeric part of the filename
    sorted_files = sorted(files, key=extract_number)
    
    for file_name in sorted_files:
        file_path = os.path.join(folder_path, file_name)
        logging.info(f'Processing file: {file_name}')
        #process_file(file_path, output_folder_path)

# %%
warnings.filterwarnings(action='ignore', category=FutureWarning)

# Configure logging to write to a file and the console
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(filename='processing.log'),
        logging.StreamHandler()
    ]
)

input_folder_path = '../data/tracking_tweetids_2023-03'
output_folder_path = '../data/output/tracking_tweetids_2023-03_splitted'

# Create output folder if it doesn't exist
os.makedirs(output_folder_path, exist_ok=True)  
process_all_files_in_folder(input_folder_path, output_folder_path)
# process_file(input_file, output_folder_path)
logging.info('Done processing all files')
# Out:
# 2023-10-29 18:19:48,710 - root - INFO - Processing file: tracking_tweetids_2023-03_633.txt
# 2023-10-29 18:19:48,710 - root - INFO - Processing file: tracking_tweetids_2023-03_587.txt
# 2023-10-29 18:19:48,711 - root - INFO - Processing file: tracking_tweetids_2023-03_487.txt
# 2023-10-29 18:19:48,711 - root - INFO - Processing file: tracking_tweetids_2023-03_647.txt
# 2023-10-29 18:19:48,712 - root - INFO - Processing file: tracking_tweetids_2023-03_798.txt
# 2023-10-29 18:19:48,712 - root - INFO - Processing file: tracking_tweetids_2023-03_1026.txt
# 2023-10-29 18:19:48,713 - root - INFO - Processing file: tracking_tweetids_2023-03_881.txt
# 2023-10-29 18:19:48,714 - root - INFO - Processing file: tracking_tweetids_2023-03_571.txt
# 2023-10-29 18:19:48,714 - root - INFO - Processing file: tracking_tweetids_2023-03_1053.txt
# 2023-10-29 18:19:48,714 - root - INFO - Processing file: tracking_tweetids_2023-03_212.txt
# 2023-10-29 18:19:48,715 - root - INFO - Processing file: tracking_tweetids_2023-03_550.txt
# 2023-10-29 18:19:48,716 - root - INFO - Processing file: tracking_tweetids_2023-03_432.txt
# 2023-10-29 18:19:48,716 - root - INFO - Processing file: tracking_tweetids_2023-03_391.txt
# 2023-10-29 18:19:48,717 - root - INFO - Processing file: tracking_tweetids_2023-03_810.txt
# 2023-10-29 18:19:48,717 - root - INFO - Processing file: tracking_tweetids_2023-03_850.txt
# 2023-10-29 18:19:48,718 - root - INFO - Processing file: tracking_tweetids_2023-03_821.txt
# 2023-10-29 18:19:48,718 - root - INFO - Processing file: tracking_tweetids_2023-03_927.txt
# 2023-10-29 18:19:48,719 - root - INFO - Processing file: tracking_tweetids_2023-03_481.txt
# 2023-10-29 18:19:48,719 - root - INFO - Processing file: tracking_tweetids_2023-03_924.txt
# 2023-10-29 18:19:48,720 - root - INFO - Processing file: tracking_tweetids_2023-03_166.txt
# 2023-10-29 18:19:48,720 - root - INFO - Processing file: tracking_tweetids_2023-03_974.txt
# 2023-10-29 18:19:48,720 - root - INFO - Processing file: tracking_tweetids_2023-03_1005.txt
# 2023-10-29 18:19:48,721 - root - INFO - Processing file: tracking_tweetids_2023-03_1032.txt
# 2023-10-29 18:19:48,721 - root - INFO - Processing file: tracking_tweetids_2023-03_512.txt
# 2023-10-29 18:19:48,722 - root - INFO - Processing file: tracking_tweetids_2023-03_794.txt
# 2023-10-29 18:19:48,722 - root - INFO - Processing file: tracking_tweetids_2023-03_1001.txt
# 2023-10-29 18:19:48,723 - root - INFO - Processing file: tracking_tweetids_2023-03_786.txt
# 2023-10-29 18:19:48,723 - root - INFO - Processing file: tracking_tweetids_2023-03_672.txt
# 2023-10-29 18:19:48,723 - root - INFO - Processing file: tracking_tweetids_2023-03_82.txt
# 2023-10-29 18:19:48,724 - root - INFO - Processing file: tracking_tweetids_2023-03_782.txt
# 2023-10-29 18:19:48,724 - root - INFO - Processing file: tracking_tweetids_2023-03_342.txt
# 2023-10-29 18:19:48,725 - root - INFO - Processing file: tracking_tweetids_2023-03_857.txt
# 2023-10-29 18:19:48,725 - root - INFO - Processing file: tracking_tweetids_2023-03_946.txt
# 2023-10-29 18:19:48,726 - root - INFO - Processing file: tracking_tweetids_2023-03_961.txt
# 2023-10-29 18:19:48,726 - root - INFO - Processing file: tracking_tweetids_2023-03_182.txt
# 2023-10-29 18:19:48,727 - root - INFO - Processing file: tracking_tweetids_2023-03_488.txt
# 2023-10-29 18:19:48,727 - root - INFO - Processing file: tracking_tweetids_2023-03_552.txt
# 2023-10-29 18:19:48,727 - root - INFO - Processing file: tracking_tweetids_2023-03_1079.txt
# 2023-10-29 18:19:48,728 - root - INFO - Processing file: tracking_tweetids_2023-03_753.txt
# 2023-10-29 18:19:48,728 - root - INFO - Processing file: tracking_tweetids_2023-03_538.txt
# 2023-10-29 18:19:48,729 - root - INFO - Processing file: tracking_tweetids_2023-03_186.txt
# 2023-10-29 18:19:48,729 - root - INFO - Processing file: tracking_tweetids_2023-03_73.txt
# 2023-10-29 18:19:48,730 - root - INFO - Processing file: tracking_tweetids_2023-03_127.txt
# 2023-10-29 18:19:48,730 - root - INFO - Processing file: tracking_tweetids_2023-03_1100.txt
# 2023-10-29 18:19:48,731 - root - INFO - Processing file: tracking_tweetids_2023-03_125.txt
# 2023-10-29 18:19:48,731 - root - INFO - Processing file: tracking_tweetids_2023-03_157.txt
# 2023-10-29 18:19:48,732 - root - INFO - Processing file: tracking_tweetids_2023-03_581.txt
# 2023-10-29 18:19:48,735 - root - INFO - Processing file: tracking_tweetids_2023-03_760.txt
# 2023-10-29 18:19:48,736 - root - INFO - Processing file: tracking_tweetids_2023-03_465.txt
# 2023-10-29 18:19:48,737 - root - INFO - Processing file: tracking_tweetids_2023-03_199.txt
# 2023-10-29 18:19:48,737 - root - INFO - Processing file: tracking_tweetids_2023-03_62.txt
# 2023-10-29 18:19:48,737 - root - INFO - Processing file: tracking_tweetids_2023-03_307.txt
# 2023-10-29 18:19:48,738 - root - INFO - Processing file: tracking_tweetids_2023-03_670.txt
# 2023-10-29 18:19:48,738 - root - INFO - Processing file: tracking_tweetids_2023-03_372.txt
# 2023-10-29 18:19:48,739 - root - INFO - Processing file: tracking_tweetids_2023-03_105.txt
# 2023-10-29 18:19:48,739 - root - INFO - Processing file: tracking_tweetids_2023-03_151.txt
# 2023-10-29 18:19:48,740 - root - INFO - Processing file: tracking_tweetids_2023-03_1116.txt
# 2023-10-29 18:19:48,741 - root - INFO - Processing file: tracking_tweetids_2023-03_362.txt
# 2023-10-29 18:19:48,741 - root - INFO - Processing file: tracking_tweetids_2023-03_1092.txt
# 2023-10-29 18:19:48,742 - root - INFO - Processing file: tracking_tweetids_2023-03_392.txt
# 2023-10-29 18:19:48,742 - root - INFO - Processing file: tracking_tweetids_2023-03_359.txt
# 2023-10-29 18:19:48,743 - root - INFO - Processing file: tracking_tweetids_2023-03_1076.txt
# 2023-10-29 18:19:48,744 - root - INFO - Processing file: tracking_tweetids_2023-03_555.txt
# 2023-10-29 18:19:48,744 - root - INFO - Processing file: tracking_tweetids_2023-03_113.txt
# 2023-10-29 18:19:48,745 - root - INFO - Processing file: tracking_tweetids_2023-03_607.txt
# 2023-10-29 18:19:48,745 - root - INFO - Processing file: tracking_tweetids_2023-03_367.txt
# 2023-10-29 18:19:48,746 - root - INFO - Processing file: tracking_tweetids_2023-03_895.txt
# 2023-10-29 18:19:48,746 - root - INFO - Processing file: tracking_tweetids_2023-03_830.txt
# 2023-10-29 18:19:48,746 - root - INFO - Processing file: tracking_tweetids_2023-03_496.txt
# 2023-10-29 18:19:48,747 - root - INFO - Processing file: tracking_tweetids_2023-03_349.txt
# 2023-10-29 18:19:48,748 - root - INFO - Processing file: tracking_tweetids_2023-03_87.txt
# 2023-10-29 18:19:48,748 - root - INFO - Processing file: tracking_tweetids_2023-03_326.txt
# 2023-10-29 18:19:48,748 - root - INFO - Processing file: tracking_tweetids_2023-03_289.txt
# 2023-10-29 18:19:48,749 - root - INFO - Processing file: tracking_tweetids_2023-03_738.txt
# 2023-10-29 18:19:48,749 - root - INFO - Processing file: tracking_tweetids_2023-03_699.txt
# 2023-10-29 18:19:48,750 - root - INFO - Processing file: tracking_tweetids_2023-03_245.txt
# 2023-10-29 18:19:48,750 - root - INFO - Processing file: tracking_tweetids_2023-03_746.txt
# 2023-10-29 18:19:48,751 - root - INFO - Processing file: tracking_tweetids_2023-03_107.txt
# 2023-10-29 18:19:48,751 - root - INFO - Processing file: tracking_tweetids_2023-03_15.txt
# 2023-10-29 18:19:48,752 - root - INFO - Processing file: tracking_tweetids_2023-03_953.txt
# 2023-10-29 18:19:48,752 - root - INFO - Processing file: tracking_tweetids_2023-03_799.txt
# 2023-10-29 18:19:48,753 - root - INFO - Processing file: tracking_tweetids_2023-03_915.txt
# 2023-10-29 18:19:48,753 - root - INFO - Processing file: tracking_tweetids_2023-03_823.txt
# 2023-10-29 18:19:48,753 - root - INFO - Processing file: tracking_tweetids_2023-03_69.txt
# 2023-10-29 18:19:48,754 - root - INFO - Processing file: tracking_tweetids_2023-03_842.txt
# 2023-10-29 18:19:48,754 - root - INFO - Processing file: tracking_tweetids_2023-03_1067.txt
# 2023-10-29 18:19:48,755 - root - INFO - Processing file: tracking_tweetids_2023-03_1029.txt
# 2023-10-29 18:19:48,755 - root - INFO - Processing file: tracking_tweetids_2023-03_1047.txt
# 2023-10-29 18:19:48,756 - root - INFO - Processing file: tracking_tweetids_2023-03_865.txt
# 2023-10-29 18:19:48,756 - root - INFO - Processing file: tracking_tweetids_2023-03_1020.txt
# 2023-10-29 18:19:48,757 - root - INFO - Processing file: tracking_tweetids_2023-03_116.txt
# 2023-10-29 18:19:48,757 - root - INFO - Processing file: tracking_tweetids_2023-03_451.txt
# 2023-10-29 18:19:48,757 - root - INFO - Processing file: tracking_tweetids_2023-03_251.txt
# 2023-10-29 18:19:48,758 - root - INFO - Processing file: tracking_tweetids_2023-03_960.txt
# 2023-10-29 18:19:48,758 - root - INFO - Processing file: tracking_tweetids_2023-03_327.txt
# 2023-10-29 18:19:48,759 - root - INFO - Processing file: tracking_tweetids_2023-03_677.txt
# 2023-10-29 18:19:48,759 - root - INFO - Processing file: tracking_tweetids_2023-03_213.txt
# 2023-10-29 18:19:48,760 - root - INFO - Processing file: tracking_tweetids_2023-03_1033.txt
# 2023-10-29 18:19:48,760 - root - INFO - Processing file: tracking_tweetids_2023-03_594.txt
# 2023-10-29 18:19:48,761 - root - INFO - Processing file: tracking_tweetids_2023-03_382.txt
# 2023-10-29 18:19:48,761 - root - INFO - Processing file: tracking_tweetids_2023-03_601.txt
# 2023-10-29 18:19:48,762 - root - INFO - Processing file: tracking_tweetids_2023-03_347.txt
# 2023-10-29 18:19:48,762 - root - INFO - Processing file: tracking_tweetids_2023-03_153.txt
# 2023-10-29 18:19:48,762 - root - INFO - Processing file: tracking_tweetids_2023-03_99.txt
# 2023-10-29 18:19:48,763 - root - INFO - Processing file: tracking_tweetids_2023-03_81.txt
# 2023-10-29 18:19:48,763 - root - INFO - Processing file: tracking_tweetids_2023-03_795.txt
# 2023-10-29 18:19:48,764 - root - INFO - Processing file: tracking_tweetids_2023-03_489.txt
# 2023-10-29 18:19:48,764 - root - INFO - Processing file: tracking_tweetids_2023-03_154.txt
# 2023-10-29 18:19:48,765 - root - INFO - Processing file: tracking_tweetids_2023-03_518.txt
# 2023-10-29 18:19:48,765 - root - INFO - Processing file: tracking_tweetids_2023-03_112.txt
# 2023-10-29 18:19:48,766 - root - INFO - Processing file: tracking_tweetids_2023-03_997.txt
# 2023-10-29 18:19:48,766 - root - INFO - Processing file: tracking_tweetids_2023-03_720.txt
# 2023-10-29 18:19:48,767 - root - INFO - Processing file: tracking_tweetids_2023-03_845.txt
# 2023-10-29 18:19:48,767 - root - INFO - Processing file: tracking_tweetids_2023-03_211.txt
# 2023-10-29 18:19:48,767 - root - INFO - Processing file: tracking_tweetids_2023-03_767.txt
# 2023-10-29 18:19:48,768 - root - INFO - Processing file: tracking_tweetids_2023-03_8.txt
# 2023-10-29 18:19:48,768 - root - INFO - Processing file: tracking_tweetids_2023-03_189.txt
# 2023-10-29 18:19:48,769 - root - INFO - Processing file: tracking_tweetids_2023-03_635.txt
# 2023-10-29 18:19:48,769 - root - INFO - Processing file: tracking_tweetids_2023-03_888.txt
# 2023-10-29 18:19:48,770 - root - INFO - Processing file: tracking_tweetids_2023-03_333.txt
# 2023-10-29 18:19:48,770 - root - INFO - Processing file: tracking_tweetids_2023-03_406.txt
# 2023-10-29 18:19:48,771 - root - INFO - Processing file: tracking_tweetids_2023-03_598.txt
# 2023-10-29 18:19:48,771 - root - INFO - Processing file: tracking_tweetids_2023-03_759.txt
# 2023-10-29 18:19:48,771 - root - INFO - Processing file: tracking_tweetids_2023-03_929.txt
# 2023-10-29 18:19:48,772 - root - INFO - Processing file: tracking_tweetids_2023-03_449.txt
# 2023-10-29 18:19:48,772 - root - INFO - Processing file: tracking_tweetids_2023-03_420.txt
# 2023-10-29 18:19:48,773 - root - INFO - Processing file: tracking_tweetids_2023-03_394.txt
# 2023-10-29 18:19:48,773 - root - INFO - Processing file: tracking_tweetids_2023-03_335.txt
# 2023-10-29 18:19:48,774 - root - INFO - Processing file: tracking_tweetids_2023-03_419.txt
# 2023-10-29 18:19:48,774 - root - INFO - Processing file: tracking_tweetids_2023-03_989.txt
# 2023-10-29 18:19:48,775 - root - INFO - Processing file: tracking_tweetids_2023-03_36.txt
# 2023-10-29 18:19:48,775 - root - INFO - Processing file: tracking_tweetids_2023-03_891.txt
# 2023-10-29 18:19:48,776 - root - INFO - Processing file: tracking_tweetids_2023-03_1021.txt
# 2023-10-29 18:19:48,776 - root - INFO - Processing file: tracking_tweetids_2023-03_553.txt
# 2023-10-29 18:19:48,776 - root - INFO - Processing file: tracking_tweetids_2023-03_825.txt
# 2023-10-29 18:19:48,777 - root - INFO - Processing file: tracking_tweetids_2023-03_608.txt
# 2023-10-29 18:19:48,777 - root - INFO - Processing file: tracking_tweetids_2023-03_272.txt
# 2023-10-29 18:19:48,777 - root - INFO - Processing file: tracking_tweetids_2023-03_942.txt
# 2023-10-29 18:19:48,778 - root - INFO - Processing file: tracking_tweetids_2023-03_877.txt
# 2023-10-29 18:19:48,778 - root - INFO - Processing file: tracking_tweetids_2023-03_41.txt
# 2023-10-29 18:19:48,778 - root - INFO - Processing file: tracking_tweetids_2023-03_68.txt
# 2023-10-29 18:19:48,779 - root - INFO - Processing file: tracking_tweetids_2023-03_22.txt
# 2023-10-29 18:19:48,779 - root - INFO - Processing file: tracking_tweetids_2023-03_657.txt
# 2023-10-29 18:19:48,784 - root - INFO - Processing file: tracking_tweetids_2023-03_540.txt
# 2023-10-29 18:19:48,784 - root - INFO - Processing file: tracking_tweetids_2023-03_691.txt
# 2023-10-29 18:19:48,785 - root - INFO - Processing file: tracking_tweetids_2023-03_839.txt
# 2023-10-29 18:19:48,785 - root - INFO - Processing file: tracking_tweetids_2023-03_572.txt
# 2023-10-29 18:19:48,786 - root - INFO - Processing file: tracking_tweetids_2023-03_663.txt
# 2023-10-29 18:19:48,786 - root - INFO - Processing file: tracking_tweetids_2023-03_1083.txt
# 2023-10-29 18:19:48,787 - root - INFO - Processing file: tracking_tweetids_2023-03_987.txt
# 2023-10-29 18:19:48,787 - root - INFO - Processing file: tracking_tweetids_2023-03_668.txt
# 2023-10-29 18:19:48,787 - root - INFO - Processing file: tracking_tweetids_2023-03_437.txt
# 2023-10-29 18:19:48,788 - root - INFO - Processing file: tracking_tweetids_2023-03_803.txt
# 2023-10-29 18:19:48,788 - root - INFO - Processing file: tracking_tweetids_2023-03_966.txt
# 2023-10-29 18:19:48,789 - root - INFO - Processing file: tracking_tweetids_2023-03_320.txt
# 2023-10-29 18:19:48,789 - root - INFO - Processing file: tracking_tweetids_2023-03_472.txt
# 2023-10-29 18:19:48,790 - root - INFO - Processing file: tracking_tweetids_2023-03_806.txt
# 2023-10-29 18:19:48,790 - root - INFO - Processing file: tracking_tweetids_2023-03_643.txt
# 2023-10-29 18:19:48,791 - root - INFO - Processing file: tracking_tweetids_2023-03_468.txt
# 2023-10-29 18:19:48,791 - root - INFO - Processing file: tracking_tweetids_2023-03_405.txt
# 2023-10-29 18:19:48,792 - root - INFO - Processing file: tracking_tweetids_2023-03_313.txt
# 2023-10-29 18:19:48,792 - root - INFO - Processing file: tracking_tweetids_2023-03_976.txt
# 2023-10-29 18:19:48,793 - root - INFO - Processing file: tracking_tweetids_2023-03_363.txt
# 2023-10-29 18:19:48,793 - root - INFO - Processing file: tracking_tweetids_2023-03_181.txt
# 2023-10-29 18:19:48,793 - root - INFO - Processing file: tracking_tweetids_2023-03_440.txt
# 2023-10-29 18:19:48,794 - root - INFO - Processing file: tracking_tweetids_2023-03_533.txt
# 2023-10-29 18:19:48,794 - root - INFO - Processing file: tracking_tweetids_2023-03_728.txt
# 2023-10-29 18:19:48,794 - root - INFO - Processing file: tracking_tweetids_2023-03_658.txt
# 2023-10-29 18:19:48,795 - root - INFO - Processing file: tracking_tweetids_2023-03_279.txt
# 2023-10-29 18:19:48,796 - root - INFO - Processing file: tracking_tweetids_2023-03_597.txt
# 2023-10-29 18:19:48,796 - root - INFO - Processing file: tracking_tweetids_2023-03_19.txt
# 2023-10-29 18:19:48,797 - root - INFO - Processing file: tracking_tweetids_2023-03_972.txt
# 2023-10-29 18:19:48,797 - root - INFO - Processing file: tracking_tweetids_2023-03_879.txt
# 2023-10-29 18:19:48,797 - root - INFO - Processing file: tracking_tweetids_2023-03_726.txt
# 2023-10-29 18:19:48,798 - root - INFO - Processing file: tracking_tweetids_2023-03_427.txt
# 2023-10-29 18:19:48,798 - root - INFO - Processing file: tracking_tweetids_2023-03_644.txt
# 2023-10-29 18:19:48,799 - root - INFO - Processing file: tracking_tweetids_2023-03_688.txt
# 2023-10-29 18:19:48,799 - root - INFO - Processing file: tracking_tweetids_2023-03_926.txt
# 2023-10-29 18:19:48,800 - root - INFO - Processing file: tracking_tweetids_2023-03_669.txt
# 2023-10-29 18:19:48,800 - root - INFO - Processing file: tracking_tweetids_2023-03_171.txt
# 2023-10-29 18:19:48,800 - root - INFO - Processing file: tracking_tweetids_2023-03_841.txt
# 2023-10-29 18:19:48,801 - root - INFO - Processing file: tracking_tweetids_2023-03_747.txt
# 2023-10-29 18:19:48,801 - root - INFO - Processing file: tracking_tweetids_2023-03_491.txt
# 2023-10-29 18:19:48,802 - root - INFO - Processing file: tracking_tweetids_2023-03_967.txt
# 2023-10-29 18:19:48,802 - root - INFO - Processing file: tracking_tweetids_2023-03_613.txt
# 2023-10-29 18:19:48,802 - root - INFO - Processing file: tracking_tweetids_2023-03_334.txt
# 2023-10-29 18:19:48,803 - root - INFO - Processing file: tracking_tweetids_2023-03_656.txt
# 2023-10-29 18:19:48,804 - root - INFO - Processing file: tracking_tweetids_2023-03_1018.txt
# 2023-10-29 18:19:48,804 - root - INFO - Processing file: tracking_tweetids_2023-03_818.txt
# 2023-10-29 18:19:48,804 - root - INFO - Processing file: tracking_tweetids_2023-03_1068.txt
# 2023-10-29 18:19:48,805 - root - INFO - Processing file: tracking_tweetids_2023-03_146.txt
# 2023-10-29 18:19:48,805 - root - INFO - Processing file: tracking_tweetids_2023-03_28.txt
# 2023-10-29 18:19:48,805 - root - INFO - Processing file: tracking_tweetids_2023-03_620.txt
# 2023-10-29 18:19:48,806 - root - INFO - Processing file: tracking_tweetids_2023-03_700.txt
# 2023-10-29 18:19:48,806 - root - INFO - Processing file: tracking_tweetids_2023-03_524.txt
# 2023-10-29 18:19:48,807 - root - INFO - Processing file: tracking_tweetids_2023-03_222.txt
# 2023-10-29 18:19:48,807 - root - INFO - Processing file: tracking_tweetids_2023-03_312.txt
# 2023-10-29 18:19:48,808 - root - INFO - Processing file: tracking_tweetids_2023-03_268.txt
# 2023-10-29 18:19:48,808 - root - INFO - Processing file: tracking_tweetids_2023-03_248.txt
# 2023-10-29 18:19:48,808 - root - INFO - Processing file: tracking_tweetids_2023-03_400.txt
# 2023-10-29 18:19:48,809 - root - INFO - Processing file: tracking_tweetids_2023-03_196.txt
# 2023-10-29 18:19:48,809 - root - INFO - Processing file: tracking_tweetids_2023-03_51.txt
# 2023-10-29 18:19:48,809 - root - INFO - Processing file: tracking_tweetids_2023-03_1077.txt
# 2023-10-29 18:19:48,810 - root - INFO - Processing file: tracking_tweetids_2023-03_749.txt
# 2023-10-29 18:19:48,811 - root - INFO - Processing file: tracking_tweetids_2023-03_480.txt
# 2023-10-29 18:19:48,811 - root - INFO - Processing file: tracking_tweetids_2023-03_410.txt
# 2023-10-29 18:19:48,811 - root - INFO - Processing file: tracking_tweetids_2023-03_645.txt
# 2023-10-29 18:19:48,812 - root - INFO - Processing file: tracking_tweetids_2023-03_894.txt
# 2023-10-29 18:19:48,812 - root - INFO - Processing file: tracking_tweetids_2023-03_145.txt
# 2023-10-29 18:19:48,813 - root - INFO - Processing file: tracking_tweetids_2023-03_131.txt
# 2023-10-29 18:19:48,813 - root - INFO - Processing file: tracking_tweetids_2023-03_731.txt
# 2023-10-29 18:19:48,814 - root - INFO - Processing file: tracking_tweetids_2023-03_100.txt
# 2023-10-29 18:19:48,814 - root - INFO - Processing file: tracking_tweetids_2023-03_377.txt
# 2023-10-29 18:19:48,815 - root - INFO - Processing file: tracking_tweetids_2023-03_599.txt
# 2023-10-29 18:19:48,815 - root - INFO - Processing file: tracking_tweetids_2023-03_887.txt
# 2023-10-29 18:19:48,816 - root - INFO - Processing file: tracking_tweetids_2023-03_590.txt
# 2023-10-29 18:19:48,816 - root - INFO - Processing file: tracking_tweetids_2023-03_1106.txt
# 2023-10-29 18:19:48,816 - root - INFO - Processing file: tracking_tweetids_2023-03_159.txt
# 2023-10-29 18:19:48,817 - root - INFO - Processing file: tracking_tweetids_2023-03_861.txt
# 2023-10-29 18:19:48,817 - root - INFO - Processing file: tracking_tweetids_2023-03_484.txt
# 2023-10-29 18:19:48,818 - root - INFO - Processing file: tracking_tweetids_2023-03_797.txt
# 2023-10-29 18:19:48,818 - root - INFO - Processing file: tracking_tweetids_2023-03_901.txt
# 2023-10-29 18:19:48,819 - root - INFO - Processing file: tracking_tweetids_2023-03_683.txt
# 2023-10-29 18:19:48,819 - root - INFO - Processing file: tracking_tweetids_2023-03_37.txt
# 2023-10-29 18:19:48,820 - root - INFO - Processing file: tracking_tweetids_2023-03_371.txt
# 2023-10-29 18:19:48,820 - root - INFO - Processing file: tracking_tweetids_2023-03_284.txt
# 2023-10-29 18:19:48,821 - root - INFO - Processing file: tracking_tweetids_2023-03_46.txt
# 2023-10-29 18:19:48,821 - root - INFO - Processing file: tracking_tweetids_2023-03_256.txt
# 2023-10-29 18:19:48,822 - root - INFO - Processing file: tracking_tweetids_2023-03_840.txt
# 2023-10-29 18:19:48,822 - root - INFO - Processing file: tracking_tweetids_2023-03_434.txt
# 2023-10-29 18:19:48,822 - root - INFO - Processing file: tracking_tweetids_2023-03_703.txt
# 2023-10-29 18:19:48,823 - root - INFO - Processing file: tracking_tweetids_2023-03_360.txt
# 2023-10-29 18:19:48,823 - root - INFO - Processing file: tracking_tweetids_2023-03_408.txt
# 2023-10-29 18:19:48,824 - root - INFO - Processing file: tracking_tweetids_2023-03_610.txt
# 2023-10-29 18:19:48,824 - root - INFO - Processing file: tracking_tweetids_2023-03_1019.txt
# 2023-10-29 18:19:48,824 - root - INFO - Processing file: tracking_tweetids_2023-03_541.txt
# 2023-10-29 18:19:48,825 - root - INFO - Processing file: tracking_tweetids_2023-03_1110.txt
# 2023-10-29 18:19:48,826 - root - INFO - Processing file: tracking_tweetids_2023-03_1002.txt
# 2023-10-29 18:19:48,826 - root - INFO - Processing file: tracking_tweetids_2023-03_108.txt
# 2023-10-29 18:19:48,827 - root - INFO - Processing file: tracking_tweetids_2023-03_605.txt
# 2023-10-29 18:19:48,827 - root - INFO - Processing file: tracking_tweetids_2023-03_269.txt
# 2023-10-29 18:19:48,828 - root - INFO - Processing file: tracking_tweetids_2023-03_209.txt
# 2023-10-29 18:19:48,828 - root - INFO - Processing file: tracking_tweetids_2023-03_936.txt
# 2023-10-29 18:19:48,829 - root - INFO - Processing file: tracking_tweetids_2023-03_76.txt
# 2023-10-29 18:19:48,830 - root - INFO - Processing file: tracking_tweetids_2023-03_39.txt
# 2023-10-29 18:19:48,830 - root - INFO - Processing file: tracking_tweetids_2023-03_981.txt
# 2023-10-29 18:19:48,831 - root - INFO - Processing file: tracking_tweetids_2023-03_562.txt
# 2023-10-29 18:19:48,831 - root - INFO - Processing file: tracking_tweetids_2023-03_959.txt
# 2023-10-29 18:19:48,832 - root - INFO - Processing file: tracking_tweetids_2023-03_687.txt
# 2023-10-29 18:19:48,832 - root - INFO - Processing file: tracking_tweetids_2023-03_529.txt
# 2023-10-29 18:19:48,833 - root - INFO - Processing file: tracking_tweetids_2023-03_1078.txt
# 2023-10-29 18:19:48,833 - root - INFO - Processing file: tracking_tweetids_2023-03_220.txt
# 2023-10-29 18:19:48,834 - root - INFO - Processing file: tracking_tweetids_2023-03_1054.txt
# 2023-10-29 18:19:48,835 - root - INFO - Processing file: tracking_tweetids_2023-03_520.txt
# 2023-10-29 18:19:48,835 - root - INFO - Processing file: tracking_tweetids_2023-03_704.txt
# 2023-10-29 18:19:48,836 - root - INFO - Processing file: tracking_tweetids_2023-03_433.txt
# 2023-10-29 18:19:48,836 - root - INFO - Processing file: tracking_tweetids_2023-03_1041.txt
# 2023-10-29 18:19:48,837 - root - INFO - Processing file: tracking_tweetids_2023-03_3.txt
# 2023-10-29 18:19:48,837 - root - INFO - Processing file: tracking_tweetids_2023-03_242.txt
# 2023-10-29 18:19:48,838 - root - INFO - Processing file: tracking_tweetids_2023-03_91.txt
# 2023-10-29 18:19:48,839 - root - INFO - Processing file: tracking_tweetids_2023-03_983.txt
# 2023-10-29 18:19:48,839 - root - INFO - Processing file: tracking_tweetids_2023-03_998.txt
# 2023-10-29 18:19:48,840 - root - INFO - Processing file: tracking_tweetids_2023-03_115.txt
# 2023-10-29 18:19:48,840 - root - INFO - Processing file: tracking_tweetids_2023-03_453.txt
# 2023-10-29 18:19:48,841 - root - INFO - Processing file: tracking_tweetids_2023-03_379.txt
# 2023-10-29 18:19:48,841 - root - INFO - Processing file: tracking_tweetids_2023-03_744.txt
# 2023-10-29 18:19:48,842 - root - INFO - Processing file: tracking_tweetids_2023-03_600.txt
# 2023-10-29 18:19:48,843 - root - INFO - Processing file: tracking_tweetids_2023-03_142.txt
# 2023-10-29 18:19:48,843 - root - INFO - Processing file: tracking_tweetids_2023-03_328.txt
# 2023-10-29 18:19:48,844 - root - INFO - Processing file: tracking_tweetids_2023-03_875.txt
# 2023-10-29 18:19:48,845 - root - INFO - Processing file: tracking_tweetids_2023-03_941.txt
# 2023-10-29 18:19:48,845 - root - INFO - Processing file: tracking_tweetids_2023-03_483.txt
# 2023-10-29 18:19:48,846 - root - INFO - Processing file: tracking_tweetids_2023-03_709.txt
# 2023-10-29 18:19:48,847 - root - INFO - Processing file: tracking_tweetids_2023-03_884.txt
# 2023-10-29 18:19:48,848 - root - INFO - Processing file: tracking_tweetids_2023-03_103.txt
# 2023-10-29 18:19:48,849 - root - INFO - Processing file: tracking_tweetids_2023-03_64.txt
# 2023-10-29 18:19:48,850 - root - INFO - Processing file: tracking_tweetids_2023-03_192.txt
# 2023-10-29 18:19:48,850 - root - INFO - Processing file: tracking_tweetids_2023-03_1115.txt
# 2023-10-29 18:19:48,851 - root - INFO - Processing file: tracking_tweetids_2023-03_321.txt
# 2023-10-29 18:19:48,852 - root - INFO - Processing file: tracking_tweetids_2023-03_409.txt
# 2023-10-29 18:19:48,852 - root - INFO - Processing file: tracking_tweetids_2023-03_12.txt
# 2023-10-29 18:19:48,853 - root - INFO - Processing file: tracking_tweetids_2023-03_18.txt
# 2023-10-29 18:19:48,854 - root - INFO - Processing file: tracking_tweetids_2023-03_678.txt
# 2023-10-29 18:19:48,854 - root - INFO - Processing file: tracking_tweetids_2023-03_702.txt
# 2023-10-29 18:19:48,855 - root - INFO - Processing file: tracking_tweetids_2023-03_973.txt
# 2023-10-29 18:19:48,856 - root - INFO - Processing file: tracking_tweetids_2023-03_807.txt
# 2023-10-29 18:19:48,857 - root - INFO - Processing file: tracking_tweetids_2023-03_904.txt
# 2023-10-29 18:19:48,857 - root - INFO - Processing file: tracking_tweetids_2023-03_413.txt
# 2023-10-29 18:19:48,858 - root - INFO - Processing file: tracking_tweetids_2023-03_71.txt
# 2023-10-29 18:19:48,858 - root - INFO - Processing file: tracking_tweetids_2023-03_421.txt
# 2023-10-29 18:19:48,859 - root - INFO - Processing file: tracking_tweetids_2023-03_381.txt
# 2023-10-29 18:19:48,860 - root - INFO - Processing file: tracking_tweetids_2023-03_903.txt
# 2023-10-29 18:19:48,860 - root - INFO - Processing file: tracking_tweetids_2023-03_85.txt
# 2023-10-29 18:19:48,861 - root - INFO - Processing file: tracking_tweetids_2023-03_1090.txt
# 2023-10-29 18:19:48,862 - root - INFO - Processing file: tracking_tweetids_2023-03_988.txt
# 2023-10-29 18:19:48,862 - root - INFO - Processing file: tracking_tweetids_2023-03_714.txt
# 2023-10-29 18:19:48,863 - root - INFO - Processing file: tracking_tweetids_2023-03_177.txt
# 2023-10-29 18:19:48,864 - root - INFO - Processing file: tracking_tweetids_2023-03_902.txt
# 2023-10-29 18:19:48,864 - root - INFO - Processing file: tracking_tweetids_2023-03_819.txt
# 2023-10-29 18:19:48,865 - root - INFO - Processing file: tracking_tweetids_2023-03_723.txt
# 2023-10-29 18:19:48,866 - root - INFO - Processing file: tracking_tweetids_2023-03_374.txt
# 2023-10-29 18:19:48,866 - root - INFO - Processing file: tracking_tweetids_2023-03_636.txt
# 2023-10-29 18:19:48,867 - root - INFO - Processing file: tracking_tweetids_2023-03_619.txt
# 2023-10-29 18:19:48,868 - root - INFO - Processing file: tracking_tweetids_2023-03_1008.txt
# 2023-10-29 18:19:48,868 - root - INFO - Processing file: tracking_tweetids_2023-03_833.txt
# 2023-10-29 18:19:48,869 - root - INFO - Processing file: tracking_tweetids_2023-03_325.txt
# 2023-10-29 18:19:48,870 - root - INFO - Processing file: tracking_tweetids_2023-03_811.txt
# 2023-10-29 18:19:48,870 - root - INFO - Processing file: tracking_tweetids_2023-03_686.txt
# 2023-10-29 18:19:48,871 - root - INFO - Processing file: tracking_tweetids_2023-03_239.txt
# 2023-10-29 18:19:48,872 - root - INFO - Processing file: tracking_tweetids_2023-03_448.txt
# 2023-10-29 18:19:48,872 - root - INFO - Processing file: tracking_tweetids_2023-03_155.txt
# 2023-10-29 18:19:48,873 - root - INFO - Processing file: tracking_tweetids_2023-03_261.txt
# 2023-10-29 18:19:48,874 - root - INFO - Processing file: tracking_tweetids_2023-03_412.txt
# 2023-10-29 18:19:48,875 - root - INFO - Processing file: tracking_tweetids_2023-03_593.txt
# 2023-10-29 18:19:48,875 - root - INFO - Processing file: tracking_tweetids_2023-03_859.txt
# 2023-10-29 18:19:48,876 - root - INFO - Processing file: tracking_tweetids_2023-03_964.txt
# 2023-10-29 18:19:48,877 - root - INFO - Processing file: tracking_tweetids_2023-03_838.txt
# 2023-10-29 18:19:48,877 - root - INFO - Processing file: tracking_tweetids_2023-03_758.txt
# 2023-10-29 18:19:48,878 - root - INFO - Processing file: tracking_tweetids_2023-03_734.txt
# 2023-10-29 18:19:48,878 - root - INFO - Processing file: tracking_tweetids_2023-03_86.txt
# 2023-10-29 18:19:48,879 - root - INFO - Processing file: tracking_tweetids_2023-03_885.txt
# 2023-10-29 18:19:48,880 - root - INFO - Processing file: tracking_tweetids_2023-03_843.txt
# 2023-10-29 18:19:48,881 - root - INFO - Processing file: tracking_tweetids_2023-03_820.txt
# 2023-10-29 18:19:48,881 - root - INFO - Processing file: tracking_tweetids_2023-03_343.txt
# 2023-10-29 18:19:48,882 - root - INFO - Processing file: tracking_tweetids_2023-03_10.txt
# 2023-10-29 18:19:48,883 - root - INFO - Processing file: tracking_tweetids_2023-03_43.txt
# 2023-10-29 18:19:48,883 - root - INFO - Processing file: tracking_tweetids_2023-03_1093.txt
# 2023-10-29 18:19:48,884 - root - INFO - Processing file: tracking_tweetids_2023-03_890.txt
# 2023-10-29 18:19:48,885 - root - INFO - Processing file: tracking_tweetids_2023-03_498.txt
# 2023-10-29 18:19:48,885 - root - INFO - Processing file: tracking_tweetids_2023-03_844.txt
# 2023-10-29 18:19:48,886 - root - INFO - Processing file: tracking_tweetids_2023-03_1.txt
# 2023-10-29 18:19:48,886 - root - INFO - Processing file: tracking_tweetids_2023-03_267.txt
# 2023-10-29 18:19:48,887 - root - INFO - Processing file: tracking_tweetids_2023-03_160.txt
# 2023-10-29 18:19:48,888 - root - INFO - Processing file: tracking_tweetids_2023-03_278.txt
# 2023-10-29 18:19:48,889 - root - INFO - Processing file: tracking_tweetids_2023-03_918.txt
# 2023-10-29 18:19:48,889 - root - INFO - Processing file: tracking_tweetids_2023-03_210.txt
# 2023-10-29 18:19:48,890 - root - INFO - Processing file: tracking_tweetids_2023-03_60.txt
# 2023-10-29 18:19:48,891 - root - INFO - Processing file: tracking_tweetids_2023-03_564.txt
# 2023-10-29 18:19:48,891 - root - INFO - Processing file: tracking_tweetids_2023-03_986.txt
# 2023-10-29 18:19:48,892 - root - INFO - Processing file: tracking_tweetids_2023-03_530.txt
# 2023-10-29 18:19:48,892 - root - INFO - Processing file: tracking_tweetids_2023-03_1036.txt
# 2023-10-29 18:19:48,893 - root - INFO - Processing file: tracking_tweetids_2023-03_831.txt
# 2023-10-29 18:19:48,894 - root - INFO - Processing file: tracking_tweetids_2023-03_208.txt
# 2023-10-29 18:19:48,895 - root - INFO - Processing file: tracking_tweetids_2023-03_502.txt
# 2023-10-29 18:19:48,895 - root - INFO - Processing file: tracking_tweetids_2023-03_143.txt
# 2023-10-29 18:19:48,896 - root - INFO - Processing file: tracking_tweetids_2023-03_623.txt
# 2023-10-29 18:19:48,896 - root - INFO - Processing file: tracking_tweetids_2023-03_676.txt
# 2023-10-29 18:19:48,897 - root - INFO - Processing file: tracking_tweetids_2023-03_505.txt
# 2023-10-29 18:19:48,898 - root - INFO - Processing file: tracking_tweetids_2023-03_492.txt
# 2023-10-29 18:19:48,899 - root - INFO - Processing file: tracking_tweetids_2023-03_61.txt
# 2023-10-29 18:19:48,899 - root - INFO - Processing file: tracking_tweetids_2023-03_117.txt
# 2023-10-29 18:19:48,900 - root - INFO - Processing file: tracking_tweetids_2023-03_497.txt
# 2023-10-29 18:19:48,901 - root - INFO - Processing file: tracking_tweetids_2023-03_584.txt
# 2023-10-29 18:19:48,901 - root - INFO - Processing file: tracking_tweetids_2023-03_979.txt
# 2023-10-29 18:19:48,902 - root - INFO - Processing file: tracking_tweetids_2023-03_283.txt
# 2023-10-29 18:19:48,902 - root - INFO - Processing file: tracking_tweetids_2023-03_1048.txt
# 2023-10-29 18:19:48,903 - root - INFO - Processing file: tracking_tweetids_2023-03_975.txt
# 2023-10-29 18:19:48,903 - root - INFO - Processing file: tracking_tweetids_2023-03_869.txt
# 2023-10-29 18:19:48,905 - root - INFO - Processing file: tracking_tweetids_2023-03_763.txt
# 2023-10-29 18:19:48,905 - root - INFO - Processing file: tracking_tweetids_2023-03_693.txt
# 2023-10-29 18:19:48,906 - root - INFO - Processing file: tracking_tweetids_2023-03_292.txt
# 2023-10-29 18:19:48,907 - root - INFO - Processing file: tracking_tweetids_2023-03_459.txt
# 2023-10-29 18:19:48,907 - root - INFO - Processing file: tracking_tweetids_2023-03_369.txt
# 2023-10-29 18:19:48,908 - root - INFO - Processing file: tracking_tweetids_2023-03_1112.txt
# 2023-10-29 18:19:48,908 - root - INFO - Processing file: tracking_tweetids_2023-03_648.txt
# 2023-10-29 18:19:48,909 - root - INFO - Processing file: tracking_tweetids_2023-03_397.txt
# 2023-10-29 18:19:48,909 - root - INFO - Processing file: tracking_tweetids_2023-03_1022.txt
# 2023-10-29 18:19:48,910 - root - INFO - Processing file: tracking_tweetids_2023-03_991.txt
# 2023-10-29 18:19:48,910 - root - INFO - Processing file: tracking_tweetids_2023-03_762.txt
# 2023-10-29 18:19:48,911 - root - INFO - Processing file: tracking_tweetids_2023-03_238.txt
# 2023-10-29 18:19:48,911 - root - INFO - Processing file: tracking_tweetids_2023-03_937.txt
# 2023-10-29 18:19:48,912 - root - INFO - Processing file: tracking_tweetids_2023-03_517.txt
# 2023-10-29 18:19:48,913 - root - INFO - Processing file: tracking_tweetids_2023-03_426.txt
# 2023-10-29 18:19:48,913 - root - INFO - Processing file: tracking_tweetids_2023-03_606.txt
# 2023-10-29 18:19:48,914 - root - INFO - Processing file: tracking_tweetids_2023-03_866.txt
# 2023-10-29 18:19:48,914 - root - INFO - Processing file: tracking_tweetids_2023-03_244.txt
# 2023-10-29 18:19:48,915 - root - INFO - Processing file: tracking_tweetids_2023-03_139.txt
# 2023-10-29 18:19:48,915 - root - INFO - Processing file: tracking_tweetids_2023-03_724.txt
# 2023-10-29 18:19:48,916 - root - INFO - Processing file: tracking_tweetids_2023-03_293.txt
# 2023-10-29 18:19:48,916 - root - INFO - Processing file: tracking_tweetids_2023-03_652.txt
# 2023-10-29 18:19:48,917 - root - INFO - Processing file: tracking_tweetids_2023-03_928.txt
# 2023-10-29 18:19:48,917 - root - INFO - Processing file: tracking_tweetids_2023-03_921.txt
# 2023-10-29 18:19:48,918 - root - INFO - Processing file: tracking_tweetids_2023-03_692.txt
# 2023-10-29 18:19:48,918 - root - INFO - Processing file: tracking_tweetids_2023-03_495.txt
# 2023-10-29 18:19:48,919 - root - INFO - Processing file: tracking_tweetids_2023-03_933.txt
# 2023-10-29 18:19:48,920 - root - INFO - Processing file: tracking_tweetids_2023-03_507.txt
# 2023-10-29 18:19:48,920 - root - INFO - Processing file: tracking_tweetids_2023-03_188.txt
# 2023-10-29 18:19:48,921 - root - INFO - Processing file: tracking_tweetids_2023-03_445.txt
# 2023-10-29 18:19:48,921 - root - INFO - Processing file: tracking_tweetids_2023-03_549.txt
# 2023-10-29 18:19:48,922 - root - INFO - Processing file: tracking_tweetids_2023-03_947.txt
# 2023-10-29 18:19:48,922 - root - INFO - Processing file: tracking_tweetids_2023-03_660.txt
# 2023-10-29 18:19:48,923 - root - INFO - Processing file: tracking_tweetids_2023-03_511.txt
# 2023-10-29 18:19:48,923 - root - INFO - Processing file: tracking_tweetids_2023-03_615.txt
# 2023-10-29 18:19:48,924 - root - INFO - Processing file: tracking_tweetids_2023-03_537.txt
# 2023-10-29 18:19:48,925 - root - INFO - Processing file: tracking_tweetids_2023-03_761.txt
# 2023-10-29 18:19:48,925 - root - INFO - Processing file: tracking_tweetids_2023-03_905.txt
# 2023-10-29 18:19:48,925 - root - INFO - Processing file: tracking_tweetids_2023-03_521.txt
# 2023-10-29 18:19:48,926 - root - INFO - Processing file: tracking_tweetids_2023-03_589.txt
# 2023-10-29 18:19:48,926 - root - INFO - Processing file: tracking_tweetids_2023-03_479.txt
# 2023-10-29 18:19:48,927 - root - INFO - Processing file: tracking_tweetids_2023-03_5.txt
# 2023-10-29 18:19:48,927 - root - INFO - Processing file: tracking_tweetids_2023-03_66.txt
# 2023-10-29 18:19:48,928 - root - INFO - Processing file: tracking_tweetids_2023-03_302.txt
# 2023-10-29 18:19:48,928 - root - INFO - Processing file: tracking_tweetids_2023-03_1063.txt
# 2023-10-29 18:19:48,929 - root - INFO - Processing file: tracking_tweetids_2023-03_205.txt
# 2023-10-29 18:19:48,929 - root - INFO - Processing file: tracking_tweetids_2023-03_779.txt
# 2023-10-29 18:19:48,930 - root - INFO - Processing file: tracking_tweetids_2023-03_971.txt
# 2023-10-29 18:19:48,930 - root - INFO - Processing file: tracking_tweetids_2023-03_1082.txt
# 2023-10-29 18:19:48,931 - root - INFO - Processing file: tracking_tweetids_2023-03_978.txt
# 2023-10-29 18:19:48,931 - root - INFO - Processing file: tracking_tweetids_2023-03_556.txt
# 2023-10-29 18:19:48,932 - root - INFO - Processing file: tracking_tweetids_2023-03_217.txt
# 2023-10-29 18:19:48,932 - root - INFO - Processing file: tracking_tweetids_2023-03_558.txt
# 2023-10-29 18:19:48,933 - root - INFO - Processing file: tracking_tweetids_2023-03_486.txt
# 2023-10-29 18:19:48,933 - root - INFO - Processing file: tracking_tweetids_2023-03_33.txt
# 2023-10-29 18:19:48,934 - root - INFO - Processing file: tracking_tweetids_2023-03_907.txt
# 2023-10-29 18:19:48,934 - root - INFO - Processing file: tracking_tweetids_2023-03_403.txt
# 2023-10-29 18:19:48,935 - root - INFO - Processing file: tracking_tweetids_2023-03_454.txt
# 2023-10-29 18:19:48,935 - root - INFO - Processing file: tracking_tweetids_2023-03_900.txt
# 2023-10-29 18:19:48,936 - root - INFO - Processing file: tracking_tweetids_2023-03_356.txt
# 2023-10-29 18:19:48,936 - root - INFO - Processing file: tracking_tweetids_2023-03_286.txt
# 2023-10-29 18:19:48,937 - root - INFO - Processing file: tracking_tweetids_2023-03_287.txt
# 2023-10-29 18:19:48,937 - root - INFO - Processing file: tracking_tweetids_2023-03_339.txt
# 2023-10-29 18:19:48,938 - root - INFO - Processing file: tracking_tweetids_2023-03_1066.txt
# 2023-10-29 18:19:48,938 - root - INFO - Processing file: tracking_tweetids_2023-03_851.txt
# 2023-10-29 18:19:48,939 - root - INFO - Processing file: tracking_tweetids_2023-03_444.txt
# 2023-10-29 18:19:48,939 - root - INFO - Processing file: tracking_tweetids_2023-03_561.txt
# 2023-10-29 18:19:48,940 - root - INFO - Processing file: tracking_tweetids_2023-03_285.txt
# 2023-10-29 18:19:48,940 - root - INFO - Processing file: tracking_tweetids_2023-03_523.txt
# 2023-10-29 18:19:48,941 - root - INFO - Processing file: tracking_tweetids_2023-03_311.txt
# 2023-10-29 18:19:48,941 - root - INFO - Processing file: tracking_tweetids_2023-03_430.txt
# 2023-10-29 18:19:48,942 - root - INFO - Processing file: tracking_tweetids_2023-03_868.txt
# 2023-10-29 18:19:48,942 - root - INFO - Processing file: tracking_tweetids_2023-03_187.txt
# 2023-10-29 18:19:48,943 - root - INFO - Processing file: tracking_tweetids_2023-03_25.txt
# 2023-10-29 18:19:48,943 - root - INFO - Processing file: tracking_tweetids_2023-03_775.txt
# 2023-10-29 18:19:48,944 - root - INFO - Processing file: tracking_tweetids_2023-03_1091.txt
# 2023-10-29 18:19:48,944 - root - INFO - Processing file: tracking_tweetids_2023-03_560.txt
# 2023-10-29 18:19:48,945 - root - INFO - Processing file: tracking_tweetids_2023-03_31.txt
# 2023-10-29 18:19:48,945 - root - INFO - Processing file: tracking_tweetids_2023-03_1104.txt
# 2023-10-29 18:19:48,945 - root - INFO - Processing file: tracking_tweetids_2023-03_1011.txt
# 2023-10-29 18:19:48,946 - root - INFO - Processing file: tracking_tweetids_2023-03_250.txt
# 2023-10-29 18:19:48,946 - root - INFO - Processing file: tracking_tweetids_2023-03_120.txt
# 2023-10-29 18:19:48,947 - root - INFO - Processing file: tracking_tweetids_2023-03_29.txt
# 2023-10-29 18:19:48,947 - root - INFO - Processing file: tracking_tweetids_2023-03_1016.txt
# 2023-10-29 18:19:48,948 - root - INFO - Processing file: tracking_tweetids_2023-03_354.txt
# 2023-10-29 18:19:48,948 - root - INFO - Processing file: tracking_tweetids_2023-03_993.txt
# 2023-10-29 18:19:48,949 - root - INFO - Processing file: tracking_tweetids_2023-03_235.txt
# 2023-10-29 18:19:48,949 - root - INFO - Processing file: tracking_tweetids_2023-03_49.txt
# 2023-10-29 18:19:48,950 - root - INFO - Processing file: tracking_tweetids_2023-03_370.txt
# 2023-10-29 18:19:48,950 - root - INFO - Processing file: tracking_tweetids_2023-03_736.txt
# 2023-10-29 18:19:48,951 - root - INFO - Processing file: tracking_tweetids_2023-03_701.txt
# 2023-10-29 18:19:48,952 - root - INFO - Processing file: tracking_tweetids_2023-03_170.txt
# 2023-10-29 18:19:48,952 - root - INFO - Processing file: tracking_tweetids_2023-03_134.txt
# 2023-10-29 18:19:48,952 - root - INFO - Processing file: tracking_tweetids_2023-03_229.txt
# 2023-10-29 18:19:48,953 - root - INFO - Processing file: tracking_tweetids_2023-03_917.txt
# 2023-10-29 18:19:48,953 - root - INFO - Processing file: tracking_tweetids_2023-03_1025.txt
# 2023-10-29 18:19:48,954 - root - INFO - Processing file: tracking_tweetids_2023-03_40.txt
# 2023-10-29 18:19:48,954 - root - INFO - Processing file: tracking_tweetids_2023-03_344.txt
# 2023-10-29 18:19:48,954 - root - INFO - Processing file: tracking_tweetids_2023-03_732.txt
# 2023-10-29 18:19:48,955 - root - INFO - Processing file: tracking_tweetids_2023-03_1085.txt
# 2023-10-29 18:19:48,955 - root - INFO - Processing file: tracking_tweetids_2023-03_503.txt
# 2023-10-29 18:19:48,956 - root - INFO - Processing file: tracking_tweetids_2023-03_801.txt
# 2023-10-29 18:19:48,956 - root - INFO - Processing file: tracking_tweetids_2023-03_1073.txt
# 2023-10-29 18:19:48,957 - root - INFO - Processing file: tracking_tweetids_2023-03_148.txt
# 2023-10-29 18:19:48,957 - root - INFO - Processing file: tracking_tweetids_2023-03_778.txt
# 2023-10-29 18:19:48,957 - root - INFO - Processing file: tracking_tweetids_2023-03_276.txt
# 2023-10-29 18:19:48,958 - root - INFO - Processing file: tracking_tweetids_2023-03_295.txt
# 2023-10-29 18:19:48,958 - root - INFO - Processing file: tracking_tweetids_2023-03_737.txt
# 2023-10-29 18:19:48,959 - root - INFO - Processing file: tracking_tweetids_2023-03_846.txt
# 2023-10-29 18:19:48,959 - root - INFO - Processing file: tracking_tweetids_2023-03_274.txt
# 2023-10-29 18:19:48,960 - root - INFO - Processing file: tracking_tweetids_2023-03_968.txt
# 2023-10-29 18:19:48,960 - root - INFO - Processing file: tracking_tweetids_2023-03_277.txt
# 2023-10-29 18:19:48,960 - root - INFO - Processing file: tracking_tweetids_2023-03_602.txt
# 2023-10-29 18:19:48,960 - root - INFO - Processing file: tracking_tweetids_2023-03_0.txt
# 2023-10-29 18:19:48,961 - root - INFO - Processing file: tracking_tweetids_2023-03_214.txt
# 2023-10-29 18:19:48,962 - root - INFO - Processing file: tracking_tweetids_2023-03_661.txt
# 2023-10-29 18:19:48,962 - root - INFO - Processing file: tracking_tweetids_2023-03_1065.txt
# 2023-10-29 18:19:48,963 - root - INFO - Processing file: tracking_tweetids_2023-03_58.txt
# 2023-10-29 18:19:48,963 - root - INFO - Processing file: tracking_tweetids_2023-03_1044.txt
# 2023-10-29 18:19:48,963 - root - INFO - Processing file: tracking_tweetids_2023-03_1043.txt
# 2023-10-29 18:19:48,964 - root - INFO - Processing file: tracking_tweetids_2023-03_306.txt
# 2023-10-29 18:19:48,964 - root - INFO - Processing file: tracking_tweetids_2023-03_1034.txt
# 2023-10-29 18:19:48,964 - root - INFO - Processing file: tracking_tweetids_2023-03_1075.txt
# 2023-10-29 18:19:48,965 - root - INFO - Processing file: tracking_tweetids_2023-03_172.txt
# 2023-10-29 18:19:48,965 - root - INFO - Processing file: tracking_tweetids_2023-03_756.txt
# 2023-10-29 18:19:48,966 - root - INFO - Processing file: tracking_tweetids_2023-03_882.txt
# 2023-10-29 18:19:48,966 - root - INFO - Processing file: tracking_tweetids_2023-03_463.txt
# 2023-10-29 18:19:48,966 - root - INFO - Processing file: tracking_tweetids_2023-03_852.txt
# 2023-10-29 18:19:48,967 - root - INFO - Processing file: tracking_tweetids_2023-03_59.txt
# 2023-10-29 18:19:48,967 - root - INFO - Processing file: tracking_tweetids_2023-03_793.txt
# 2023-10-29 18:19:48,968 - root - INFO - Processing file: tracking_tweetids_2023-03_893.txt
# 2023-10-29 18:19:48,968 - root - INFO - Processing file: tracking_tweetids_2023-03_443.txt
# 2023-10-29 18:19:48,968 - root - INFO - Processing file: tracking_tweetids_2023-03_30.txt
# 2023-10-29 18:19:48,969 - root - INFO - Processing file: tracking_tweetids_2023-03_253.txt
# 2023-10-29 18:19:48,969 - root - INFO - Processing file: tracking_tweetids_2023-03_163.txt
# 2023-10-29 18:19:48,970 - root - INFO - Processing file: tracking_tweetids_2023-03_654.txt
# 2023-10-29 18:19:48,970 - root - INFO - Processing file: tracking_tweetids_2023-03_384.txt
# 2023-10-29 18:19:48,971 - root - INFO - Processing file: tracking_tweetids_2023-03_977.txt
# 2023-10-29 18:19:48,971 - root - INFO - Processing file: tracking_tweetids_2023-03_240.txt
# 2023-10-29 18:19:48,971 - root - INFO - Processing file: tracking_tweetids_2023-03_1024.txt
# 2023-10-29 18:19:48,972 - root - INFO - Processing file: tracking_tweetids_2023-03_219.txt
# 2023-10-29 18:19:48,972 - root - INFO - Processing file: tracking_tweetids_2023-03_316.txt
# 2023-10-29 18:19:48,973 - root - INFO - Processing file: tracking_tweetids_2023-03_999.txt
# 2023-10-29 18:19:48,973 - root - INFO - Processing file: tracking_tweetids_2023-03_225.txt
# 2023-10-29 18:19:48,974 - root - INFO - Processing file: tracking_tweetids_2023-03_45.txt
# 2023-10-29 18:19:48,974 - root - INFO - Processing file: tracking_tweetids_2023-03_1087.txt
# 2023-10-29 18:19:48,974 - root - INFO - Processing file: tracking_tweetids_2023-03_450.txt
# 2023-10-29 18:19:48,975 - root - INFO - Processing file: tracking_tweetids_2023-03_791.txt
# 2023-10-29 18:19:48,975 - root - INFO - Processing file: tracking_tweetids_2023-03_402.txt
# 2023-10-29 18:19:48,976 - root - INFO - Processing file: tracking_tweetids_2023-03_789.txt
# 2023-10-29 18:19:48,976 - root - INFO - Processing file: tracking_tweetids_2023-03_768.txt
# 2023-10-29 18:19:48,976 - root - INFO - Processing file: tracking_tweetids_2023-03_6.txt
# 2023-10-29 18:19:48,977 - root - INFO - Processing file: tracking_tweetids_2023-03_551.txt
# 2023-10-29 18:19:48,977 - root - INFO - Processing file: tracking_tweetids_2023-03_858.txt
# 2023-10-29 18:19:48,978 - root - INFO - Processing file: tracking_tweetids_2023-03_461.txt
# 2023-10-29 18:19:48,978 - root - INFO - Processing file: tracking_tweetids_2023-03_88.txt
# 2023-10-29 18:19:48,978 - root - INFO - Processing file: tracking_tweetids_2023-03_715.txt
# 2023-10-29 18:19:48,979 - root - INFO - Processing file: tracking_tweetids_2023-03_579.txt
# 2023-10-29 18:19:48,979 - root - INFO - Processing file: tracking_tweetids_2023-03_401.txt
# 2023-10-29 18:19:48,980 - root - INFO - Processing file: tracking_tweetids_2023-03_455.txt
# 2023-10-29 18:19:48,980 - root - INFO - Processing file: tracking_tweetids_2023-03_1118.txt
# 2023-10-29 18:19:48,981 - root - INFO - Processing file: tracking_tweetids_2023-03_513.txt
# 2023-10-29 18:19:48,981 - root - INFO - Processing file: tracking_tweetids_2023-03_1105.txt
# 2023-10-29 18:19:48,982 - root - INFO - Processing file: tracking_tweetids_2023-03_389.txt
# 2023-10-29 18:19:48,982 - root - INFO - Processing file: tracking_tweetids_2023-03_54.txt
# 2023-10-29 18:19:48,982 - root - INFO - Processing file: tracking_tweetids_2023-03_423.txt
# 2023-10-29 18:19:48,983 - root - INFO - Processing file: tracking_tweetids_2023-03_47.txt
# 2023-10-29 18:19:48,983 - root - INFO - Processing file: tracking_tweetids_2023-03_257.txt
# 2023-10-29 18:19:48,983 - root - INFO - Processing file: tracking_tweetids_2023-03_1042.txt
# ...
# 2023-10-29 18:19:49,217 - root - INFO - Processing file: tracking_tweetids_2023-03_566.txt
# 2023-10-29 18:19:49,217 - root - INFO - Processing file: tracking_tweetids_2023-03_862.txt
# 2023-10-29 18:19:49,218 - root - INFO - Processing file: tracking_tweetids_2023-03_198.txt
# 2023-10-29 18:19:49,218 - root - INFO - Processing file: tracking_tweetids_2023-03_730.txt
# 2023-10-29 18:19:49,219 - root - INFO - Processing file: tracking_tweetids_2023-03_909.txt
# 2023-10-29 18:19:49,220 - root - INFO - Processing file: tracking_tweetids_2023-03_666.txt
# 2023-10-29 18:19:49,220 - root - INFO - Processing file: tracking_tweetids_2023-03_515.txt
# 2023-10-29 18:19:49,221 - root - INFO - Processing file: tracking_tweetids_2023-03_586.txt
# 2023-10-29 18:19:49,222 - root - INFO - Processing file: tracking_tweetids_2023-03_48.txt
# 2023-10-29 18:19:49,222 - root - INFO - Processing file: tracking_tweetids_2023-03_94.txt
# 2023-10-29 18:19:49,223 - root - INFO - Processing file: tracking_tweetids_2023-03_698.txt
# 2023-10-29 18:19:49,224 - root - INFO - Processing file: tracking_tweetids_2023-03_452.txt
# 2023-10-29 18:19:49,224 - root - INFO - Processing file: tracking_tweetids_2023-03_227.txt
# 2023-10-29 18:19:49,225 - root - INFO - Processing file: tracking_tweetids_2023-03_1037.txt
# 2023-10-29 18:19:49,226 - root - INFO - Processing file: tracking_tweetids_2023-03_357.txt
# 2023-10-29 18:19:49,226 - root - INFO - Processing file: tracking_tweetids_2023-03_574.txt
# 2023-10-29 18:19:49,227 - root - INFO - Processing file: tracking_tweetids_2023-03_826.txt
# 2023-10-29 18:19:49,227 - root - INFO - Processing file: tracking_tweetids_2023-03_376.txt
# 2023-10-29 18:19:49,228 - root - INFO - Processing file: tracking_tweetids_2023-03_14.txt
# 2023-10-29 18:19:49,229 - root - INFO - Processing file: tracking_tweetids_2023-03_642.txt
# 2023-10-29 18:19:49,229 - root - INFO - Processing file: tracking_tweetids_2023-03_348.txt
# 2023-10-29 18:19:49,230 - root - INFO - Processing file: tracking_tweetids_2023-03_317.txt
# 2023-10-29 18:19:49,231 - root - INFO - Processing file: tracking_tweetids_2023-03_174.txt
# 2023-10-29 18:19:49,231 - root - INFO - Processing file: tracking_tweetids_2023-03_44.txt
# 2023-10-29 18:19:49,232 - root - INFO - Processing file: tracking_tweetids_2023-03_102.txt
# 2023-10-29 18:19:49,233 - root - INFO - Processing file: tracking_tweetids_2023-03_580.txt
# 2023-10-29 18:19:49,234 - root - INFO - Processing file: tracking_tweetids_2023-03_1069.txt
# 2023-10-29 18:19:49,234 - root - INFO - Processing file: tracking_tweetids_2023-03_1071.txt
# 2023-10-29 18:19:49,235 - root - INFO - Processing file: tracking_tweetids_2023-03_525.txt
# 2023-10-29 18:19:49,236 - root - INFO - Processing file: tracking_tweetids_2023-03_816.txt
# 2023-10-29 18:19:49,236 - root - INFO - Processing file: tracking_tweetids_2023-03_330.txt
# 2023-10-29 18:19:49,237 - root - INFO - Processing file: tracking_tweetids_2023-03_111.txt
# 2023-10-29 18:19:49,237 - root - INFO - Processing file: tracking_tweetids_2023-03_129.txt
# 2023-10-29 18:19:49,238 - root - INFO - Processing file: tracking_tweetids_2023-03_1009.txt
# 2023-10-29 18:19:49,239 - root - INFO - Processing file: tracking_tweetids_2023-03_21.txt
# 2023-10-29 18:19:49,239 - root - INFO - Processing file: tracking_tweetids_2023-03_50.txt
# 2023-10-29 18:19:49,240 - root - INFO - Processing file: tracking_tweetids_2023-03_742.txt
# 2023-10-29 18:19:49,241 - root - INFO - Processing file: tracking_tweetids_2023-03_1028.txt
# 2023-10-29 18:19:49,241 - root - INFO - Processing file: tracking_tweetids_2023-03_1055.txt
# 2023-10-29 18:19:49,242 - root - INFO - Processing file: tracking_tweetids_2023-03_837.txt
# 2023-10-29 18:19:49,243 - root - INFO - Processing file: tracking_tweetids_2023-03_206.txt
# 2023-10-29 18:19:49,244 - root - INFO - Processing file: tracking_tweetids_2023-03_764.txt
# 2023-10-29 18:19:49,244 - root - INFO - Processing file: tracking_tweetids_2023-03_938.txt
# 2023-10-29 18:19:49,245 - root - INFO - Processing file: tracking_tweetids_2023-03_508.txt
# 2023-10-29 18:19:49,245 - root - INFO - Processing file: tracking_tweetids_2023-03_55.txt
# 2023-10-29 18:19:49,246 - root - INFO - Processing file: tracking_tweetids_2023-03_490.txt
# 2023-10-29 18:19:49,247 - root - INFO - Processing file: tracking_tweetids_2023-03_694.txt
# 2023-10-29 18:19:49,247 - root - INFO - Processing file: tracking_tweetids_2023-03_757.txt
# 2023-10-29 18:19:49,248 - root - INFO - Processing file: tracking_tweetids_2023-03_790.txt
# 2023-10-29 18:19:49,249 - root - INFO - Processing file: tracking_tweetids_2023-03_314.txt
# 2023-10-29 18:19:49,249 - root - INFO - Processing file: tracking_tweetids_2023-03_769.txt
# 2023-10-29 18:19:49,251 - root - INFO - Processing file: tracking_tweetids_2023-03_716.txt
# 2023-10-29 18:19:49,251 - root - INFO - Processing file: tracking_tweetids_2023-03_162.txt
# 2023-10-29 18:19:49,252 - root - INFO - Processing file: tracking_tweetids_2023-03_892.txt
# 2023-10-29 18:19:49,253 - root - INFO - Processing file: tracking_tweetids_2023-03_792.txt
# 2023-10-29 18:19:49,254 - root - INFO - Processing file: tracking_tweetids_2023-03_106.txt
# 2023-10-29 18:19:49,254 - root - INFO - Processing file: tracking_tweetids_2023-03_223.txt
# 2023-10-29 18:19:49,255 - root - INFO - Processing file: tracking_tweetids_2023-03_353.txt
# 2023-10-29 18:19:49,255 - root - INFO - Processing file: tracking_tweetids_2023-03_1015.txt
# 2023-10-29 18:19:49,256 - root - INFO - Processing file: tracking_tweetids_2023-03_682.txt
# 2023-10-29 18:19:49,257 - root - INFO - Processing file: tracking_tweetids_2023-03_1000.txt
# 2023-10-29 18:19:49,258 - root - INFO - Processing file: tracking_tweetids_2023-03_752.txt
# 2023-10-29 18:19:49,258 - root - INFO - Processing file: tracking_tweetids_2023-03_383.txt
# 2023-10-29 18:19:49,259 - root - INFO - Processing file: tracking_tweetids_2023-03_1072.txt
# 2023-10-29 18:19:49,260 - root - INFO - Processing file: tracking_tweetids_2023-03_705.txt
# 2023-10-29 18:19:49,261 - root - INFO - Processing file: tracking_tweetids_2023-03_527.txt
# 2023-10-29 18:19:49,261 - root - INFO - Processing file: tracking_tweetids_2023-03_625.txt
# 2023-10-29 18:19:49,262 - root - INFO - Processing file: tracking_tweetids_2023-03_754.txt
# 2023-10-29 18:19:49,263 - root - INFO - Processing file: tracking_tweetids_2023-03_456.txt
# 2023-10-29 18:19:49,264 - root - INFO - Processing file: tracking_tweetids_2023-03_800.txt
# 2023-10-29 18:19:49,265 - root - INFO - Processing file: tracking_tweetids_2023-03_771.txt
# 2023-10-29 18:19:49,266 - root - INFO - Processing file: tracking_tweetids_2023-03_514.txt
# 2023-10-29 18:19:49,266 - root - INFO - Processing file: tracking_tweetids_2023-03_395.txt
# 2023-10-29 18:19:49,267 - root - INFO - Processing file: tracking_tweetids_2023-03_473.txt
# 2023-10-29 18:19:49,268 - root - INFO - Processing file: tracking_tweetids_2023-03_247.txt
# 2023-10-29 18:19:49,268 - root - INFO - Processing file: tracking_tweetids_2023-03_464.txt
# 2023-10-29 18:19:49,269 - root - INFO - Processing file: tracking_tweetids_2023-03_777.txt
# 2023-10-29 18:19:49,269 - root - INFO - Processing file: tracking_tweetids_2023-03_913.txt
# 2023-10-29 18:19:49,270 - root - INFO - Processing file: tracking_tweetids_2023-03_101.txt
# 2023-10-29 18:19:49,270 - root - INFO - Processing file: tracking_tweetids_2023-03_542.txt
# 2023-10-29 18:19:49,271 - root - INFO - Processing file: tracking_tweetids_2023-03_17.txt
# 2023-10-29 18:19:49,271 - root - INFO - Processing file: tracking_tweetids_2023-03_95.txt
# 2023-10-29 18:19:49,272 - root - INFO - Processing file: tracking_tweetids_2023-03_1059.txt
# 2023-10-29 18:19:49,273 - root - INFO - Processing file: tracking_tweetids_2023-03_241.txt
# 2023-10-29 18:19:49,274 - root - INFO - Processing file: tracking_tweetids_2023-03_577.txt
# 2023-10-29 18:19:49,274 - root - INFO - Processing file: tracking_tweetids_2023-03_4.txt
# 2023-10-29 18:19:49,275 - root - INFO - Processing file: tracking_tweetids_2023-03_373.txt
# 2023-10-29 18:19:49,275 - root - INFO - Processing file: tracking_tweetids_2023-03_226.txt
# 2023-10-29 18:19:49,275 - root - INFO - Processing file: tracking_tweetids_2023-03_185.txt
# 2023-10-29 18:19:49,276 - root - INFO - Processing file: tracking_tweetids_2023-03_624.txt
# 2023-10-29 18:19:49,276 - root - INFO - Processing file: tracking_tweetids_2023-03_930.txt
# 2023-10-29 18:19:49,277 - root - INFO - Processing file: tracking_tweetids_2023-03_202.txt
# 2023-10-29 18:19:49,277 - root - INFO - Processing file: tracking_tweetids_2023-03_27.txt
# 2023-10-29 18:19:49,278 - root - INFO - Processing file: tracking_tweetids_2023-03_632.txt
# 2023-10-29 18:19:49,278 - root - INFO - Processing file: tracking_tweetids_2023-03_813.txt
# 2023-10-29 18:19:49,279 - root - INFO - Processing file: tracking_tweetids_2023-03_575.txt
# 2023-10-29 18:19:49,279 - root - INFO - Processing file: tracking_tweetids_2023-03_1052.txt
# 2023-10-29 18:19:49,280 - root - INFO - Processing file: tracking_tweetids_2023-03_940.txt
# 2023-10-29 18:19:49,281 - root - INFO - Processing file: tracking_tweetids_2023-03_207.txt
# 2023-10-29 18:19:49,281 - root - INFO - Processing file: tracking_tweetids_2023-03_690.txt
# 2023-10-29 18:19:49,282 - root - INFO - Processing file: tracking_tweetids_2023-03_855.txt
# 2023-10-29 18:19:49,282 - root - INFO - Processing file: tracking_tweetids_2023-03_808.txt
# 2023-10-29 18:19:49,283 - root - INFO - Processing file: tracking_tweetids_2023-03_200.txt
# 2023-10-29 18:19:49,283 - root - INFO - Processing file: tracking_tweetids_2023-03_74.txt
# 2023-10-29 18:19:49,284 - root - INFO - Processing file: tracking_tweetids_2023-03_447.txt
# 2023-10-29 18:19:49,284 - root - INFO - Processing file: tracking_tweetids_2023-03_856.txt
# 2023-10-29 18:19:49,285 - root - INFO - Processing file: tracking_tweetids_2023-03_1098.txt
# 2023-10-29 18:19:49,285 - root - INFO - Processing file: tracking_tweetids_2023-03_878.txt
# 2023-10-29 18:19:49,286 - root - INFO - Processing file: tracking_tweetids_2023-03_951.txt
# 2023-10-29 18:19:49,286 - root - INFO - Processing file: tracking_tweetids_2023-03_1114.txt
# 2023-10-29 18:19:49,287 - root - INFO - Processing file: tracking_tweetids_2023-03_717.txt
# 2023-10-29 18:19:49,288 - root - INFO - Processing file: tracking_tweetids_2023-03_588.txt
# 2023-10-29 18:19:49,289 - root - INFO - Processing file: tracking_tweetids_2023-03_1102.txt
# 2023-10-29 18:19:49,290 - root - INFO - Processing file: tracking_tweetids_2023-03_630.txt
# 2023-10-29 18:19:49,290 - root - INFO - Processing file: tracking_tweetids_2023-03_822.txt
# 2023-10-29 18:19:49,290 - root - INFO - Processing file: tracking_tweetids_2023-03_880.txt
# 2023-10-29 18:19:49,291 - root - INFO - Processing file: tracking_tweetids_2023-03_11.txt
# 2023-10-29 18:19:49,291 - root - INFO - Processing file: tracking_tweetids_2023-03_305.txt
# 2023-10-29 18:19:49,292 - root - INFO - Processing file: tracking_tweetids_2023-03_97.txt
# 2023-10-29 18:19:49,293 - root - INFO - Processing file: tracking_tweetids_2023-03_827.txt
# 2023-10-29 18:19:49,293 - root - INFO - Processing file: tracking_tweetids_2023-03_735.txt
# 2023-10-29 18:19:49,293 - root - INFO - Processing file: tracking_tweetids_2023-03_519.txt
# 2023-10-29 18:19:49,294 - root - INFO - Processing file: tracking_tweetids_2023-03_585.txt
# 2023-10-29 18:19:49,294 - root - INFO - Processing file: tracking_tweetids_2023-03_193.txt
# 2023-10-29 18:19:49,295 - root - INFO - Processing file: tracking_tweetids_2023-03_390.txt
# 2023-10-29 18:19:49,296 - root - INFO - Processing file: tracking_tweetids_2023-03_1064.txt
# 2023-10-29 18:19:49,296 - root - INFO - Processing file: tracking_tweetids_2023-03_310.txt
# 2023-10-29 18:19:49,297 - root - INFO - Processing file: tracking_tweetids_2023-03_236.txt
# 2023-10-29 18:19:49,297 - root - INFO - Processing file: tracking_tweetids_2023-03_266.txt
# 2023-10-29 18:19:49,298 - root - INFO - Processing file: tracking_tweetids_2023-03_713.txt
# 2023-10-29 18:19:49,298 - root - INFO - Processing file: tracking_tweetids_2023-03_684.txt
# 2023-10-29 18:19:49,299 - root - INFO - Processing file: tracking_tweetids_2023-03_510.txt
# 2023-10-29 18:19:49,299 - root - INFO - Processing file: tracking_tweetids_2023-03_414.txt
# 2023-10-29 18:19:49,300 - root - INFO - Processing file: tracking_tweetids_2023-03_504.txt
# 2023-10-29 18:19:49,300 - root - INFO - Processing file: tracking_tweetids_2023-03_80.txt
# 2023-10-29 18:19:49,301 - root - INFO - Processing file: tracking_tweetids_2023-03_2.txt
# 2023-10-29 18:19:49,303 - root - INFO - Processing file: tracking_tweetids_2023-03_646.txt
# 2023-10-29 18:19:49,303 - root - INFO - Processing file: tracking_tweetids_2023-03_309.txt
# 2023-10-29 18:19:49,304 - root - INFO - Processing file: tracking_tweetids_2023-03_104.txt
# 2023-10-29 18:19:49,305 - root - INFO - Processing file: tracking_tweetids_2023-03_246.txt
# 2023-10-29 18:19:49,305 - root - INFO - Processing file: tracking_tweetids_2023-03_428.txt
# 2023-10-29 18:19:49,306 - root - INFO - Processing file: tracking_tweetids_2023-03_1081.txt
# 2023-10-29 18:19:49,307 - root - INFO - Processing file: tracking_tweetids_2023-03_1051.txt
# 2023-10-29 18:19:49,308 - root - INFO - Processing file: tracking_tweetids_2023-03_509.txt
# 2023-10-29 18:19:49,308 - root - INFO - Processing file: tracking_tweetids_2023-03_1003.txt
# 2023-10-29 18:19:49,309 - root - INFO - Processing file: tracking_tweetids_2023-03_847.txt
# 2023-10-29 18:19:49,309 - root - INFO - Processing file: tracking_tweetids_2023-03_1058.txt
# 2023-10-29 18:19:49,313 - root - INFO - Processing file: tracking_tweetids_2023-03_164.txt
# 2023-10-29 18:19:49,314 - root - INFO - Processing file: tracking_tweetids_2023-03_260.txt
# 2023-10-29 18:19:49,315 - root - INFO - Processing file: tracking_tweetids_2023-03_358.txt
# 2023-10-29 18:19:49,316 - root - INFO - Processing file: tracking_tweetids_2023-03_366.txt
# 2023-10-29 18:19:49,317 - root - INFO - Processing file: tracking_tweetids_2023-03_478.txt
# 2023-10-29 18:19:49,317 - root - INFO - Processing file: tracking_tweetids_2023-03_603.txt
# 2023-10-29 18:19:49,317 - root - INFO - Processing file: tracking_tweetids_2023-03_628.txt
# 2023-10-29 18:19:49,318 - root - INFO - Processing file: tracking_tweetids_2023-03_853.txt
# 2023-10-29 18:19:49,319 - root - INFO - Processing file: tracking_tweetids_2023-03_567.txt
# 2023-10-29 18:19:49,320 - root - INFO - Processing file: tracking_tweetids_2023-03_429.txt
# 2023-10-29 18:19:49,320 - root - INFO - Processing file: tracking_tweetids_2023-03_318.txt
# 2023-10-29 18:19:49,321 - root - INFO - Processing file: tracking_tweetids_2023-03_195.txt
# 2023-10-29 18:19:49,322 - root - INFO - Processing file: tracking_tweetids_2023-03_536.txt
# 2023-10-29 18:19:49,322 - root - INFO - Processing file: tracking_tweetids_2023-03_725.txt
# 2023-10-29 18:19:49,323 - root - INFO - Processing file: tracking_tweetids_2023-03_493.txt
# 2023-10-29 18:19:49,324 - root - INFO - Processing file: tracking_tweetids_2023-03_667.txt
# 2023-10-29 18:19:49,324 - root - INFO - Processing file: tracking_tweetids_2023-03_173.txt
# 2023-10-29 18:19:49,325 - root - INFO - Processing file: tracking_tweetids_2023-03_380.txt
# 2023-10-29 18:19:49,326 - root - INFO - Processing file: tracking_tweetids_2023-03_346.txt
# 2023-10-29 18:19:49,327 - root - INFO - Processing file: tracking_tweetids_2023-03_128.txt
# 2023-10-29 18:19:49,327 - root - INFO - Processing file: tracking_tweetids_2023-03_591.txt
# 2023-10-29 18:19:49,328 - root - INFO - Processing file: tracking_tweetids_2023-03_996.txt
# 2023-10-29 18:19:49,328 - root - INFO - Processing file: tracking_tweetids_2023-03_470.txt
# 2023-10-29 18:19:49,329 - root - INFO - Processing file: tracking_tweetids_2023-03_609.txt
# 2023-10-29 18:19:49,329 - root - INFO - Processing file: tracking_tweetids_2023-03_616.txt
# 2023-10-29 18:19:49,331 - root - INFO - Processing file: tracking_tweetids_2023-03_275.txt
# 2023-10-29 18:19:49,332 - root - INFO - Processing file: tracking_tweetids_2023-03_1030.txt
# 2023-10-29 18:19:49,332 - root - INFO - Processing file: tracking_tweetids_2023-03_1107.txt
# 2023-10-29 18:19:49,333 - root - INFO - Done processing all files

# %%
info = fetch_additional_info(1688217309112901632)
parse_api_response(info)
# Out:
# {'lang': 'tr',
#  'favorite_count': 4842,
#  'created_at': '2023-08-06T15:55:46.000Z',
#  'text': 'İstanbul Hukuk 2023 mezuniyet töreninde konuşma yapması gereken ancak yaptırılmayan okul birincilerden biri olarak olayların çok farklı yerlere çekilmesinden, sanki tek bir kişiye, konuşmasının içeriğinden dolayı konuşma yaptırılmamış algısının yaratılmasından çok rahatsızım. https://t.co/FgEhtxJqFj',
#  'parent_tweet_id': ''}

# %%
info_str = json.loads(info)
info_str.get('entities', {})
# Out:
# {'hashtags': [],
#  'urls': [],
#  'user_mentions': [],
#  'symbols': [],
#  'media': [{'display_url': 'pic.twitter.com/FgEhtxJqFj',
#    'expanded_url': 'https://twitter.com/Berkaydyilmaz/status/1688217309112901632/photo/1',
#    'indices': [277, 300],
#    'url': 'https://t.co/FgEhtxJqFj'}]}

# %%
# TODO: look if with the new information we can extract everything we need from the API call and parse it into csv
# TODO: we need it to work for just one txt file. How is the parallelization works there?

# %%
import os

def split_file(file_path, lines_per_file, output_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Get the base name of the input file (without extension)
    base_name = os.path.basename(file_path).rsplit('.', 1)[0]

    for i in range(0, len(lines), lines_per_file):
        # Construct the path for the smaller files
        small_file_name = f"{base_name}_{i // lines_per_file}.txt"
        small_file_path = os.path.join(output_path, small_file_name)
        with open(small_file_path, 'w') as small_file:
            small_file.writelines(lines[i:i + lines_per_file])

# Ensure the output directory exists
os.makedirs('output', exist_ok=True)

# Call the function
split_file('../data/streamV2_tweetids_2023-06.txt', 100000, '../data/streamV2_tweetids_2023-06')
